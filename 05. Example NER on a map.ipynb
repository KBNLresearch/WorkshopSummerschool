# %% [markdown]
# ## Extra: example NER on a map

# %% [markdown]
# Import de benodigde packages

# %%
import pandas as pd
import spacy
from spacy import displacy
from collections import Counter
import pickle
import plotly.express as px
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# Laad de dataset

# %%
fiets_nlp = pd.read_pickle("data/fiets_nlp.pkl")

# %%
fiets_nlp.head(2)
# Out:
#        Unnamed: 0                                         identifier     type  \
# 21061       84265  http://resolver.kb.nl/resolve?urn=MMKB23:00140...  artikel
# 21072       84295  http://resolver.kb.nl/resolve?urn=ddd:01011723...  artikel
#
#                                  title                 date  \
# 21061  BUITENLAND. POLITIEK OVERZICHT.  1880/05/26 00:00:00
# 21072              Gemengde Berichten.  1869/09/20 00:00:00
#
#                                                  content subcategory category  \
# 21061  ’s Gravenhage, 25 Mei.’t Is te Berlijn een lie...       fiets    fiets
# 21072  Naar men verneemt, bloeit thans in den Hortus ...     rijwiel    fiets
#
#        Year   DL score    spatial  length  \
# 21061  1880  71.212121  Landelijk     792
# 21072  1869  77.823129  Landelijk     735
#
#                                                      doc
# 21061  (’s, Gravenhage, ,, 25, Mei.’t, Is, te, Berlij...
# 21072  (Naar, men, verneemt, ,, bloeit, thans, in, de...

# %%
fiets_nlp.Year.value_counts()
# Out:
# 1869    70
# 1883    27
# 1875    20
# 1884    16
# 1871    16
# 1876    14
# 1879    14
# 1870    12
# 1874    12
# 1878    12
# 1880    11
# 1872     9
# 1882     9
# 1881     7
# 1873     5
# 1877     1
# Name: Year, dtype: int64

# %%
def get_ner(doc, entity):
    return [ent.text for ent in doc.ents if ent.label_ == entity]

# %%
fiets_nlp['GPE'] = fiets_nlp['doc'].apply(lambda x: get_ner(x, 'GPE'))

# %%
# Load coordinates data from CSV
coordinates_df = pd.read_csv('data/nl.csv')
coordinates_df.head(2)
# Out:
#         city      lat     lng      country iso2     admin_name  capital  \
# 0    Tilburg  51.5500  5.0833  Netherlands   NL  Noord-Brabant    minor
# 1  Amsterdam  52.3728  4.8936  Netherlands   NL  Noord-Holland  primary
#
#    population  population_proper
# 0     1944588            1944588
# 1     1459402             917923

# %%
# Load coordinates data from CSV
coordinates_df = pd.read_csv('data/worldcities.csv')
coordinates_df.head(2)
# Out:
#       city city_ascii     lat       lng    country iso2 iso3 admin_name  \
# 0    Tokyo      Tokyo  35.687  139.7495      Japan   JP  JPN      Tōkyō
# 1  Jakarta    Jakarta  -6.175  106.8275  Indonesia   ID  IDN    Jakarta
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077

# %%
# Create a Python dictionary mapping city names to coordinates
city_to_coords = {row['city']: (row['lat'], row['lng']) for idx, row in coordinates_df.iterrows()}

# %%
# Function to get coordinates for GPEs
def get_gpe_coords(gpe_list):
    return [city_to_coords[gpe] for gpe in gpe_list if gpe in city_to_coords]

# Apply the function to create a new column with coordinates
fiets_nlp['GPE_coords'] = fiets_nlp['GPE'].apply(get_gpe_coords)

# Display the DataFrame
pd.set_option('display.max_colwidth', None)
display(fiets_nlp[['identifier','GPE','GPE_coords']].head())
# Out:
#                                                                  identifier  \
# 21061  http://resolver.kb.nl/resolve?urn=MMKB23:001409122:mpeg21:a00001:ocr
# 21072      http://resolver.kb.nl/resolve?urn=ddd:010117239:mpeg21:a0029:ocr
# 21076      http://resolver.kb.nl/resolve?urn=ddd:010263245:mpeg21:a0008:ocr
# 21078      http://resolver.kb.nl/resolve?urn=ddd:010117225:mpeg21:a0014:ocr
# 21079      http://resolver.kb.nl/resolve?urn=ddd:010097660:mpeg21:a0006:ocr
#
#                                                                                                GPE  \
# 21061  [Berlijn, Rome, Rome, nagaat, Granlle, Berlijn, Gladgesticht, G, Europa, Granville, Parijs]
# 21072                                                      [Zwolle, Zondag, Gorinchem, Californië]
# 21076                             [Frankrijk, Parijs, Parijs, Commun, Parijs, Rothschild, Berlijn]
# 21078                                 [gemeente Zype, Edinburg, Amerika, Parijs, Bardin, Engeland]
# 21079           [Pari, afgeloopon, Neder_nd, Do Gazelle van Antwerpen, België, Nederland, Brussel]
#
#                                                          GPE_coords
# 21061  [(43.226, -75.4909), (43.226, -75.4909), (48.8374, -1.5939)]
# 21072                           [(52.5167, 6.1), (51.8306, 4.9742)]
# 21076                                                            []
# 21078                                         [(26.3196, -98.1597)]
# 21079                                         [(29.9707, -94.0015)]

# %%
# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for coords_list in fiets_nlp['GPE_coords']:
    for coords in coords_list:
        folium.Marker(location=coords).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5eb9b2f27484fd61b1b3e285f8b70395 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5eb9b2f27484fd61b1b3e285f8b70395&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5eb9b2f27484fd61b1b3e285f8b70395 = L.map(
#                 &quot;map_5eb9b2f27484fd61b1b3e285f8b70395&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88f3febf441d3bc7db6cef53d514ef9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88f3febf441d3bc7db6cef53d514ef9b.addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_41d8d9f01ace4d4e1e4db3816b720d13 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_aa0ae11dd5fa3b48878aeb4577a07909 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_74418fdf95354ef377413c88f9ba00ba = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_c4a899c1409f154043839eb678717666 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_68d0c79235e33503e92c8309a232d885 = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_dad123dcac998caa3b597c53af98328c = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_5e7eb65e2685703ad0a3b63c8ebf56b6 = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_64e44f192870d16cbe8af974a31b95ac = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_3f83efdb8a29cc8292f3579891fbe280 = L.marker(
#                 [38.0486, -84.7258],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_ff5b8c5ea26838735dd1bfc8a3d7419e = L.marker(
#                 [44.84, -0.58],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_b7fbae4e4504a75d41651a27b533d28a = L.marker(
#                 [43.2964, 5.37],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_e70a4eedd270088580bef0e3a1f4d078 = L.marker(
#                 [36.7325, 3.0872],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_ee72febe4b9c824e0a10cbbf0b22f319 = L.marker(
#                 [42.8133, -74.0129],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_5e521fa254b016e8933a8272d3ea2db0 = L.marker(
#                 [42.942, -74.1906],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_0ca9ec07899f1dd8c2ba7dedc3523b37 = L.marker(
#                 [52.3833, 4.6333],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_25f0bef50fa0de18c2542a81e22df68e = L.marker(
#                 [52.25, 6.2],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_2af6315e3bb014f36045a6626adae8bd = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_e858414e131fbb8df26fe9576150dcee = L.marker(
#                 [51.8425, 5.8528],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_a5035deceeb05f531095f0e5c555cf06 = L.marker(
#                 [52.21, 5.97],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f8b70395);
#
#
#             var marker_4386f7a7b19fb35ebf596497a90ce74d = L.marker(
#                 [52.0908, 5.1217],
#                 {
# }
#             ).addTo(map_5eb9b2f27484fd61b1b3e285f

# %%
fiets_nlp.Year.unique()
# Out:
# array([1880, 1869, 1870, 1874, 1883, 1875, 1876, 1879, 1884, 1873, 1878,
#        1871, 1872, 1881, 1882, 1877], dtype=int64)

# %%
# Define a color mapping for each unique krantnaam
color_mapping = {
    1869: 'blue',
    1870: 'green',
    1871: 'red',
    1872: 'yellow',
    1873: 'orange',
    1874: 'brown',
    1875: 'purple',
    1876: 'lightblue',
    1877: 'pink',
    1878: 'magenta',
    1879: 'darkgreen',
    1880: 'darkblue',
    1881: 'black',  
    1882: 'black', 
    1883: 'black' ,
    1884: 'black'
    
}

# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for index, row in fiets_nlp.iterrows():
    krantnaam = row['Year']
    coords_list = row['GPE_coords']
    color = color_mapping.get(krantnaam, 'black')  # Default to black if krantnaam not in mapping
    
    for coords in coords_list:
        folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# C:\Users\mirjam\AppData\Local\Temp\ipykernel_28068\82490591.py:31: UserWarning: color argument of Icon should be one of: {'pink', 'lightgreen', 'darkred', 'blue', 'darkpurple', 'white', 'orange', 'darkblue', 'lightgray', 'lightred', 'gray', 'beige', 'black', 'darkgreen', 'cadetblue', 'purple', 'lightblue', 'green', 'red'}.
#   folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84abf425493d5c3c2dcb269a80990fb1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84abf425493d5c3c2dcb269a80990fb1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84abf425493d5c3c2dcb269a80990fb1 = L.map(
#                 &quot;map_84abf425493d5c3c2dcb269a80990fb1&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48a20c44580c2995429155c9c9164b9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48a20c44580c2995429155c9c9164b9a.addTo(map_84abf425493d5c3c2dcb269a80990fb1);
#
#
#             var marker_a7ce6952cc6c693d51e6c2db4127dc13 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_84abf425493d5c3c2dcb269a80990fb1);
#
#
#             var icon_0b589f3c333243302c79e34896cedf03 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_a7ce6952cc6c693d51e6c2db4127dc13.setIcon(icon_0b589f3c333243302c79e34896cedf03);
#
#
#             var marker_df978e13ab5bdffed378de0fe9390e20 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_84abf425493d5c3c2dcb269a80990fb1);
#
#
#             var icon_1f5502c00088671f5f23d06e2ebda54a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_df978e13ab5bdffed378de0fe9390e20.setIcon(icon_1f5502c00088671f5f23d06e2ebda54a);
#
#
#             var marker_7d16c717beb69c6700feaa92b8508660 = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_84abf425493d5c3c2dcb269a80990fb1);
#
#
#             var icon_ead839b94eb8c26f6824dc198a11bdd5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_7d16c717beb69c6700feaa92b8508660.setIcon(icon_ead839b94eb8c26f6824dc198a11bdd5);
#
#
#             var marker_039d676b053bf3f9b6c63c181fe64872 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_84abf425493d5c3c2dcb269a80990fb1);
#
#
#             var icon_a7272eb9c85e8d86dca78af0a2ec68a1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_039d676b053bf3f9b6c63c181fe64872.setIcon(icon_a7272eb9c85e8d86dca78af0a2ec68a1);
#
#
#             var marker_7cfbfa1c7870c8a59de71770d4f0bdea = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_84abf425493d5c3c2dcb269a80990fb1);
#
#
#             var icon_caed65cc99890a9b002420930962f797 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_7cfbfa1c7870c8a59de71770d4f0bdea.setIcon(icon_caed65cc99890a9b002420930962f797);
#
#
#             var marker_75a0045e74549699d754c63c540df73d = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_84abf425493d5c3c2dcb269a80990fb1);
#
#
#             var icon_dbb400fc8478fb89fb0ec51e3be52e8a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;
