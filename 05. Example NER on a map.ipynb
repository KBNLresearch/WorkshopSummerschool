# %% [markdown]
#  # Extra: voorbeeld Named Entity Recognition met een kaart

# %% [markdown]
# We kunnen Named Entity Recognition voor verschillende doeleinden gebruiken. Hieronder tonen we een voorbeeld waarin wwe de gevonden plaatsnamen uitzetten op een kaart. Zo krijg je in één overzicht direct een beeld van de verschillende locaties waarover in de kranten geschreven is.

# %% [markdown]
# Als eerste importeer je de benodigde packages

# %%
import pandas as pd
import spacy
import pickle
import plotly.express as px
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# En daarna laad je het model.

# %%
fiets_nlp = pd.read_pickle("data/fiets_nlp.pkl")

# %%
fiets_nlp.head(2)
# Out:
#        Unnamed: 0                                         identifier     type  \
# 21061       84265  http://resolver.kb.nl/resolve?urn=MMKB23:00140...  artikel
# 21072       84295  http://resolver.kb.nl/resolve?urn=ddd:01011723...  artikel
#
#                                  title                 date  \
# 21061  BUITENLAND. POLITIEK OVERZICHT.  1880/05/26 00:00:00
# 21072              Gemengde Berichten.  1869/09/20 00:00:00
#
#                                                  content subcategory category  \
# 21061  ’s Gravenhage, 25 Mei.’t Is te Berlijn een lie...       fiets    fiets
# 21072  Naar men verneemt, bloeit thans in den Hortus ...     rijwiel    fiets
#
#        Year   DL score    spatial  length  \
# 21061  1880  71.212121  Landelijk     792
# 21072  1869  77.823129  Landelijk     735
#
#                                                      doc
# 21061  (’s, Gravenhage, ,, 25, Mei.’t, Is, te, Berlij...
# 21072  (Naar, men, verneemt, ,, bloeit, thans, in, de...

# %% [markdown]
# De volgende functie wordt gebruikt om entities uit de `doc` kolom te halen.

# %%
def get_ner(doc, entity):
    return [ent.text for ent in doc.ents if ent.label_ == entity]

# %% [markdown]
# In dit geval zijn we op zoek naar steden en dorpen, dus we maken enkel een kolom aan met de `GPE` entities.

# %%
fiets_nlp['GPE'] = fiets_nlp['doc'].apply(lambda x: get_ner(x, 'GPE'))

# %% [markdown]
# Vervolgens laden we een csv bestand in met informatie over de coördinaten van een groot deel van de steden en (grotere) dorpen in de wereld. We gebruiken hiervoor de gratis versie van https://simplemaps.com/data/world-cities/

# %%
coordinates_df = pd.read_csv('data/worldcities.csv')
coordinates_df.head(2)
# Out:
#       city city_ascii     lat       lng    country iso2 iso3 admin_name  \
# 0    Tokyo      Tokyo  35.687  139.7495      Japan   JP  JPN      Tōkyō
# 1  Jakarta    Jakarta  -6.175  106.8275  Indonesia   ID  IDN    Jakarta
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077

# %% [markdown]
# Vervolgens maken we een Python dictionary aan, met de mapping van de steden/dorpen en de latitude en longitude.

# %%
city_to_coords = {row['city']: (row['lat'], row['lng']) for idx, row in coordinates_df.iterrows()}

# %% [markdown]
# Met onderstaande functie worden per locatie de coördinaten opgehaald uit bovenstaande dictionary.

# %%
def get_gpe_coords(gpe_list):
    return [city_to_coords[gpe] for gpe in gpe_list if gpe in city_to_coords]

# %% [markdown]
# Vervolgens wordt een nieuwe kolom aangemaakt, waarop we deze functie toepassen.

# %%
fiets_nlp['GPE_coords'] = fiets_nlp['GPE'].apply(get_gpe_coords)

# %% [markdown]
# Hieronder tonen we een gedeelte van het dataframe, met per artikel de kolom met de GP entiteiten en de kolom met bijbehorende coördinaten.

# %%
display(fiets_nlp[['identifier','GPE','GPE_coords']].head())
# Out:
#                                               identifier  \
# 21061  http://resolver.kb.nl/resolve?urn=MMKB23:00140...
# 21072  http://resolver.kb.nl/resolve?urn=ddd:01011723...
# 21076  http://resolver.kb.nl/resolve?urn=ddd:01026324...
# 21078  http://resolver.kb.nl/resolve?urn=ddd:01011722...
# 21079  http://resolver.kb.nl/resolve?urn=ddd:01009766...
#
#                                                      GPE  \
# 21061  [Berlijn, Rome, Rome, nagaat, Granlle, Berlijn...
# 21072            [Zwolle, Zondag, Gorinchem, Californië]
# 21076  [Frankrijk, Parijs, Parijs, Commun, Parijs, Ro...
# 21078  [gemeente Zype, Edinburg, Amerika, Parijs, Bar...
# 21079  [Pari, afgeloopon, Neder_nd, Do Gazelle van An...
#
#                                               GPE_coords
# 21061  [(43.226, -75.4909), (43.226, -75.4909), (48.8...
# 21072                [(52.5167, 6.1), (51.8306, 4.9742)]
# 21076                                                 []
# 21078                              [(26.3196, -98.1597)]
# 21079                              [(29.9707, -94.0015)]

# %% [markdown]
# Vervolgens kunnen we deze coördinaten plotten op een kaart. Dit doen we met het package `folium`.

# %%
# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for coords_list in fiets_nlp['GPE_coords']:
    for coords in coords_list:
        folium.Marker(location=coords).add_to(map)
        
# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fd915e30563a0c0663b4ccf0e6e5199 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fd915e30563a0c0663b4ccf0e6e5199&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fd915e30563a0c0663b4ccf0e6e5199 = L.map(
#                 &quot;map_5fd915e30563a0c0663b4ccf0e6e5199&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df837cce1be3c53d4103c2caa7fc7207 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df837cce1be3c53d4103c2caa7fc7207.addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_89174dfb55e1954d1c59a922820c7b6e = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_f6b3a3f1601276a0353dd9c3ceddea06 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_179cc7a13dcae8f5bbb2b6f1d70abf2b = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_90848c7335f1b409db9c720cd83114ae = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_4b32d33229856f56e38b726c78a0a6b1 = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_06f7d217f6400d96aa7efd367c3181a7 = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_aa901b8bb911f2ec46267b0bb2c0f16e = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_85e0c51bedc86585adf8666e5bbe810f = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_48711fb4b580619ce93de4403e566bbc = L.marker(
#                 [38.0486, -84.7258],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_d8c6df92872bfcdb8d5f8ea762c8081c = L.marker(
#                 [44.84, -0.58],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_25ead9d4dc5fe30c93d3b137186f8171 = L.marker(
#                 [43.2964, 5.37],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_3add1b9b5735e41d63f11689d2a24753 = L.marker(
#                 [36.7325, 3.0872],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_94116814691186ca3c7d13a91e21a68b = L.marker(
#                 [42.8133, -74.0129],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_0aacfcf7d41246e32e4605571f68f20e = L.marker(
#                 [42.942, -74.1906],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_937a26da8a6f811dace41612f4899be2 = L.marker(
#                 [52.3833, 4.6333],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_839fd55329636eaaecdd3b576c6ef760 = L.marker(
#                 [52.25, 6.2],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_13cf8cee95f84998e4f73129c3e8a42c = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_815ad8762741db4d102a34d3596dec27 = L.marker(
#                 [51.8425, 5.8528],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_ebd8e21ce0d5639afc2af1dedc08227e = L.marker(
#                 [52.21, 5.97],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0e6e5199);
#
#
#             var marker_c530b3ef15dc92788c475e4616c17db3 = L.marker(
#                 [52.0908, 5.1217],
#                 {
# }
#             ).addTo(map_5fd915e30563a0c0663b4ccf0

# %% [markdown]
# Nu zie je alle locaties op de kaart die in de artilelen genoemd worden.
#
# **Let op:** Als plaatsnamen OCR-fouten bevatten of oudere spelling hebben, dan kunnen ze niet worden gematched met het coördinatenbestand en komen ze dus niet voor op de map.

# %% [markdown]
# Nu hebben alle punten op de map eenzelfde kleur. Je kunt hier nog meer onderscheid in aanbrengen, door bijvoorbeeld verschillende categorieën een veschillende kleuren te geven.
#
# Hieronder een voorbeeld van de punten op de map gekleurd naar verspreidingsgebied (spatial).

# %%
# Define a color mapping for each unique krantnaam
color_mapping = {
    'Landelijk': 'blue',
    'Regionaal/lokaal': 'purple'    
}

# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for index, row in fiets_nlp.iterrows():
    spatial = row['spatial']
    coords_list = row['GPE_coords']
    color = color_mapping.get(spatial, 'black')  # Default to black if krantnaam not in mapping
    
    for coords in coords_list:
        folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_00db4d3d982e29c192f70dc5006c8a1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_00db4d3d982e29c192f70dc5006c8a1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_00db4d3d982e29c192f70dc5006c8a1e = L.map(
#                 &quot;map_00db4d3d982e29c192f70dc5006c8a1e&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7d04c661db3c9fe0f03e8169bbb7b44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7d04c661db3c9fe0f03e8169bbb7b44.addTo(map_00db4d3d982e29c192f70dc5006c8a1e);
#
#
#             var marker_d2fe2b40664318ed77420d27043f8d08 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_00db4d3d982e29c192f70dc5006c8a1e);
#
#
#             var icon_a7af4613c6b1d2419b1bdc6505378770 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_d2fe2b40664318ed77420d27043f8d08.setIcon(icon_a7af4613c6b1d2419b1bdc6505378770);
#
#
#             var marker_8197897a1fb07c8460650eac6764666d = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_00db4d3d982e29c192f70dc5006c8a1e);
#
#
#             var icon_aedb553acd2b466894d7b2b86375aa2d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_8197897a1fb07c8460650eac6764666d.setIcon(icon_aedb553acd2b466894d7b2b86375aa2d);
#
#
#             var marker_e39b0c60cc5015441d89877e53eb4842 = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_00db4d3d982e29c192f70dc5006c8a1e);
#
#
#             var icon_f599b206eaa31084a258226e56a48cb0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_e39b0c60cc5015441d89877e53eb4842.setIcon(icon_f599b206eaa31084a258226e56a48cb0);
#
#
#             var marker_1f9f85b8c48137e8fd3dcddddcf45a53 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_00db4d3d982e29c192f70dc5006c8a1e);
#
#
#             var icon_8f14780205aaf8c25bca2b89a0abf3af = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_1f9f85b8c48137e8fd3dcddddcf45a53.setIcon(icon_8f14780205aaf8c25bca2b89a0abf3af);
#
#
#             var marker_33241f2e09da88e474a04f19fd34b8c6 = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_00db4d3d982e29c192f70dc5006c8a1e);
#
#
#             var icon_35b6c4264cc123a42cece81b3156d9a1 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_33241f2e09da88e474a04f19fd34b8c6.setIcon(icon_35b6c4264cc123a42cece81b3156d9a1);
#
#
#             var marker_403a1f2e69e30a12f87685420565a9e8 = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_00db4d3d982e29c192f70dc5006c8a1e);
#
#
#             var icon_477291898062bbb2214dcfceb5107cc9 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-r

# %% [markdown]
# En een kaart waarop de punten gekeurd zijn naar jaar.

# %%
# Define a color mapping for each unique krantnaam
color_mapping = {
    1869: 'purple', 1870: 'green', 1871: 'red', 1872: 'pink', 1873: 'orange', 1874: 'blue',
    1875: 'darkpurple', 1876: 'lightblue', 1877: 'darkgreen', 1878: 'cadetblue', 1879: 'darkgreen',
    1880: 'darkblue', 1881: 'darkred', 1882: 'lightred', 1883: 'lightgreen', 1884: 'beige'
}

# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for index, row in fiets_nlp.iterrows():
    year = row['Year']
    coords_list = row['GPE_coords']
    color = color_mapping.get(year, 'black')  # Default to black if krantnaam not in mapping
    
    for coords in coords_list:
        folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b47e11286732220dd2683a0902eff89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b47e11286732220dd2683a0902eff89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b47e11286732220dd2683a0902eff89 = L.map(
#                 &quot;map_9b47e11286732220dd2683a0902eff89&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f50c0c866529e7037a526e87ecce6a68 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f50c0c866529e7037a526e87ecce6a68.addTo(map_9b47e11286732220dd2683a0902eff89);
#
#
#             var marker_a0b2328fa154237b0d25ad514122f617 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9b47e11286732220dd2683a0902eff89);
#
#
#             var icon_52a723d74ed9cbac229ca316f56da553 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_a0b2328fa154237b0d25ad514122f617.setIcon(icon_52a723d74ed9cbac229ca316f56da553);
#
#
#             var marker_a5207946cf2bcb58fac25334ca146666 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9b47e11286732220dd2683a0902eff89);
#
#
#             var icon_391f5abf80a92d9f1a2d1681ca6b2498 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_a5207946cf2bcb58fac25334ca146666.setIcon(icon_391f5abf80a92d9f1a2d1681ca6b2498);
#
#
#             var marker_47f67afd0bcd55519358dbf58e67bac6 = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_9b47e11286732220dd2683a0902eff89);
#
#
#             var icon_31dcb5e9ba01047d0348aaecc8575daa = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_47f67afd0bcd55519358dbf58e67bac6.setIcon(icon_31dcb5e9ba01047d0348aaecc8575daa);
#
#
#             var marker_bcdd2f0b3286ad6f1df823df2b69a6a7 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_9b47e11286732220dd2683a0902eff89);
#
#
#             var icon_91d32014942eb831641634377a877f79 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_bcdd2f0b3286ad6f1df823df2b69a6a7.setIcon(icon_91d32014942eb831641634377a877f79);
#
#
#             var marker_6bdd7d983c8e7bb6b223264688f9538c = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_9b47e11286732220dd2683a0902eff89);
#
#
#             var icon_57238be58e99ef873e9d7c675c94d943 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_6bdd7d983c8e7bb6b223264688f9538c.setIcon(icon_57238be58e99ef873e9d7c675c94d943);
#
#
#             var marker_70061ad8d859573bcb96f4c3b0188dc1 = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_9b47e11286732220dd2683a0902eff89);
#
#
#             var icon_9c2de4f1de1f1ed57a7106d9e693472b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses
