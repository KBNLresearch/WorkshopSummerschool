# %% [markdown]
#  # Extra: voorbeeld Named Entity Recognition met een kaart

# %% [markdown]
# We kunnen Named Entity Recognition voor verschillende doeleinden gebruiken. Hieronder tonen we een voorbeeld waarin wwe de gevonden plaatsnamen uitzetten op een kaart. Zo krijg je in één overzicht direct een beeld van de verschillende locaties waarover in de kranten geschreven is.

# %% [markdown]
# Als eerste importeer je de benodigde packages

# %%
import pandas as pd
import spacy
import pickle
import plotly.express as px
import matplotlib.pyplot as plt
import folium

# %% [markdown]
# En daarna laad je het model.

# %%
fiets_nlp = pd.read_pickle("data/fiets_nlp.pkl")

# %%
fiets_nlp.head(2)
# Out:
#                                               identifier     type  \
# 84265  http://resolver.kb.nl/resolve?urn=MMKB23:00140...  artikel
# 84295  http://resolver.kb.nl/resolve?urn=ddd:01011723...  artikel
#
#                                  title                 date  \
# 84265  BUITENLAND. POLITIEK OVERZICHT.  1880/05/26 00:00:00
# 84295              Gemengde Berichten.  1869/09/20 00:00:00
#
#                                                  content subcategory category  \
# 84265  ’s Gravenhage, 25 Mei.’t Is te Berlijn een lie...       fiets    fiets
# 84295  Naar men verneemt, bloeit thans in den Hortus ...     rijwiel    fiets
#
#        Year   DL score    spatial  \
# 84265  1880  71.212121  Landelijk
# 84295  1869  77.823129  Landelijk
#
#                                                      doc
# 84265  (’s, Gravenhage, ,, 25, Mei.’t, Is, te, Berlij...
# 84295  (Naar, men, verneemt, ,, bloeit, thans, in, de...

# %% [markdown]
# De volgende functie wordt gebruikt om entities uit de `doc` kolom te halen.

# %%
def get_ner(doc, entity):
    return [ent.text for ent in doc.ents if ent.label_ == entity]

# %% [markdown]
# In dit geval zijn we op zoek naar steden en dorpen, dus we maken enkel een kolom aan met de `GPE` entities.

# %%
fiets_nlp['GPE'] = fiets_nlp['doc'].apply(lambda x: get_ner(x, 'GPE'))

# %% [markdown]
# Vervolgens laden we een csv bestand in met informatie over de coördinaten van een groot deel van de steden en (grotere) dorpen in de wereld. We gebruiken hiervoor de gratis versie van https://simplemaps.com/data/world-cities/

# %%
coordinates_df = pd.read_csv('data/worldcities.csv')
coordinates_df.head(2)
# Out:
#       city city_ascii     lat       lng    country iso2 iso3 admin_name  \
# 0    Tokyo      Tokyo  35.687  139.7495      Japan   JP  JPN      Tōkyō
# 1  Jakarta    Jakarta  -6.175  106.8275  Indonesia   ID  IDN    Jakarta
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077

# %% [markdown]
# Vervolgens maken we een Python dictionary aan, met de mapping van de steden/dorpen en de latitude en longitude.

# %%
city_to_coords = {row['city']: (row['lat'], row['lng']) for idx, row in coordinates_df.iterrows()}

# %% [markdown]
# Met onderstaande functie worden per locatie de coördinaten opgehaald uit bovenstaande dictionary.

# %%
def get_gpe_coords(gpe_list):
    return [city_to_coords[gpe] for gpe in gpe_list if gpe in city_to_coords]

# %% [markdown]
# Vervolgens wordt een nieuwe kolom aangemaakt, waarop we deze functie toepassen.

# %%
fiets_nlp['GPE_coords'] = fiets_nlp['GPE'].apply(get_gpe_coords)

# %% [markdown]
# Hieronder tonen we een gedeelte van het dataframe, met per artikel de kolom met de GP entiteiten en de kolom met bijbehorende coördinaten.

# %%
display(fiets_nlp[['identifier','GPE','GPE_coords']].head())
# Out:
#                                               identifier  \
# 84265  http://resolver.kb.nl/resolve?urn=MMKB23:00140...
# 84295  http://resolver.kb.nl/resolve?urn=ddd:01011723...
# 84382  http://resolver.kb.nl/resolve?urn=ddd:01026324...
# 84384  http://resolver.kb.nl/resolve?urn=ddd:01011722...
# 84416  http://resolver.kb.nl/resolve?urn=ddd:01009766...
#
#                                                      GPE  \
# 84265  [Berlijn, Rome, Rome, nagaat, Granlle, Berlijn...
# 84295            [Zwolle, Zondag, Gorinchem, Californië]
# 84382  [Frankrijk, Parijs, Parijs, Commun, Parijs, Ro...
# 84384  [gemeente Zype, Edinburg, Amerika, Parijs, Bar...
# 84416  [Pari, afgeloopon, Neder_nd, Do Gazelle van An...
#
#                                               GPE_coords
# 84265  [(43.226, -75.4909), (43.226, -75.4909), (48.8...
# 84295                [(52.5167, 6.1), (51.8306, 4.9742)]
# 84382                                                 []
# 84384                              [(26.3196, -98.1597)]
# 84416                              [(29.9707, -94.0015)]

# %% [markdown]
# Vervolgens kunnen we deze coördinaten plotten op een kaart. Dit doen we met het package `folium`.

# %%
# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for coords_list in fiets_nlp['GPE_coords']:
    for coords in coords_list:
        folium.Marker(location=coords).add_to(map)
        
# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c651563235c4e3a2b3d3ca72bdea521 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c651563235c4e3a2b3d3ca72bdea521&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c651563235c4e3a2b3d3ca72bdea521 = L.map(
#                 &quot;map_9c651563235c4e3a2b3d3ca72bdea521&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_739892e299cc104cec7c5f5d0f13ed21 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_739892e299cc104cec7c5f5d0f13ed21.addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_ad9b9834c4e1c101e9907656a5b0958f = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_64752aee90c14d8ddf2b4b349df3afda = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_238a8254e8abf8f5a3485b215545c2d2 = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_28dfc80cb08ee540fc27ab8bb30cbc8c = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_7d1625927c3bb78e269bf12ca46906d8 = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_cd70157ef709777d4e0a8203ca535232 = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_20d91baeeaabfa2a9e8348d28e1bbf66 = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_46fe98857be2caa45461b01e386412d7 = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_6766b6315a05bb1f53c16576d6be5fe6 = L.marker(
#                 [38.0486, -84.7258],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_ac45a1f1c93087a1530c88500d0e2a7e = L.marker(
#                 [44.84, -0.58],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_f049170ed6f99728caed9e3541460985 = L.marker(
#                 [43.2964, 5.37],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_f634dc6695dc492acd8a8969d8ef0809 = L.marker(
#                 [36.7325, 3.0872],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_0a15251a260d4ec7c924acc6de9c9e8b = L.marker(
#                 [42.8133, -74.0129],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_6b8132ae4270e6039429159b8eb77323 = L.marker(
#                 [42.942, -74.1906],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_923514c64e07dc2f28a6f94e82f5cd4f = L.marker(
#                 [52.3833, 4.6333],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_e91bafd16feb32494cba1acc2b454c27 = L.marker(
#                 [52.25, 6.2],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_325a19e1dedcca95637be48b658e6288 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_37eb54fa4055e1ee4c8f76ebce0fc497 = L.marker(
#                 [51.8425, 5.8528],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_570863d2bbd8a13067da5ff3e8eed7fa = L.marker(
#                 [52.21, 5.97],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72bdea521);
#
#
#             var marker_0efd10b7c49591a443559f6cd89d569e = L.marker(
#                 [52.0908, 5.1217],
#                 {
# }
#             ).addTo(map_9c651563235c4e3a2b3d3ca72

# %% [markdown]
# Nu zie je alle locaties op de kaart die in de artilelen genoemd worden.
#
# **Let op:** Als plaatsnamen OCR-fouten bevatten of oudere spelling hebben, dan kunnen ze niet worden gematched met het coördinatenbestand en komen ze dus niet voor op de map.

# %% [markdown]
# Nu hebben alle punten op de map eenzelfde kleur. Je kunt hier nog meer onderscheid in aanbrengen, door bijvoorbeeld verschillende categorieën een veschillende kleuren te geven.
#
# Hieronder een voorbeeld van de punten op de map gekleurd naar verspreidingsgebied (spatial).

# %%
# Define a color mapping for each unique spatial
color_mapping = {
    'Landelijk': 'blue',
    'Regionaal/lokaal': 'purple'    
}

# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for index, row in fiets_nlp.iterrows():
    spatial = row['spatial']
    coords_list = row['GPE_coords']
    color = color_mapping.get(spatial, 'black')  # Default to black if krantnaam not in mapping
    
    for coords in coords_list:
        folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2 = L.map(
#                 &quot;map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96efd9680c3234c0bd819613d09570ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96efd9680c3234c0bd819613d09570ac.addTo(map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2);
#
#
#             var marker_1f124efdb1a6b7f0fa057d2323b104f9 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2);
#
#
#             var icon_330ee643cb0bc14e15cb8ed2e69ce3f2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_1f124efdb1a6b7f0fa057d2323b104f9.setIcon(icon_330ee643cb0bc14e15cb8ed2e69ce3f2);
#
#
#             var marker_71ddb4558f0a7fd5edf8593518adf271 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2);
#
#
#             var icon_80ab31896ca914f2ad11e07dd9428a10 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_71ddb4558f0a7fd5edf8593518adf271.setIcon(icon_80ab31896ca914f2ad11e07dd9428a10);
#
#
#             var marker_007e76b294176bf06823efc6cc2638a1 = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2);
#
#
#             var icon_c45fafdd0d72aeabbdc10be88eca8d8d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_007e76b294176bf06823efc6cc2638a1.setIcon(icon_c45fafdd0d72aeabbdc10be88eca8d8d);
#
#
#             var marker_849bdd059a568fcec9806554bf3a3ee3 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2);
#
#
#             var icon_c0df0baab142f528367a41d7b893ea6b = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_849bdd059a568fcec9806554bf3a3ee3.setIcon(icon_c0df0baab142f528367a41d7b893ea6b);
#
#
#             var marker_34f87277bf65c7ef380c378114bb8395 = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2);
#
#
#             var icon_488f4aa4fbd25734b196c4bfd4149847 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_34f87277bf65c7ef380c378114bb8395.setIcon(icon_488f4aa4fbd25734b196c4bfd4149847);
#
#
#             var marker_17f0b1ed412b86df72ae10e321e0db78 = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_9a6ed1be1df1c46bf24ddcb7b3d2f5c2);
#
#
#             var icon_297b913e4b6a3c0330ff34232d38c28d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-r

# %% [markdown]
# En een kaart waarop de punten gekeurd zijn naar jaar.

# %%
# Define a color mapping for each unique year
color_mapping = {
    1869: 'purple', 1870: 'green', 1871: 'red', 1872: 'pink', 1873: 'orange', 1874: 'blue',
    1875: 'darkpurple', 1876: 'lightblue', 1877: 'darkgreen', 1878: 'cadetblue', 1879: 'darkgreen',
    1880: 'darkblue', 1881: 'darkred', 1882: 'lightred', 1883: 'lightgreen', 1884: 'beige'
}

# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for index, row in fiets_nlp.iterrows():
    year = row['Year']
    coords_list = row['GPE_coords']
    color = color_mapping.get(year, 'black')  # Default to black if krantnaam not in mapping
    
    for coords in coords_list:
        folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a553afe07dc26207ec394afb520e360 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a553afe07dc26207ec394afb520e360&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a553afe07dc26207ec394afb520e360 = L.map(
#                 &quot;map_2a553afe07dc26207ec394afb520e360&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c844d5af7414939ca8478b83b139fcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c844d5af7414939ca8478b83b139fcc.addTo(map_2a553afe07dc26207ec394afb520e360);
#
#
#             var marker_2d60dfe09e1a499493e488bf8fac8c99 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_2a553afe07dc26207ec394afb520e360);
#
#
#             var icon_b9c6e94b5e02aa51430176794906f171 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_2d60dfe09e1a499493e488bf8fac8c99.setIcon(icon_b9c6e94b5e02aa51430176794906f171);
#
#
#             var marker_4dff524c253f076c87099bd8bd71c582 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_2a553afe07dc26207ec394afb520e360);
#
#
#             var icon_6b83ef52920400b4d465f01c96b0c6af = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_4dff524c253f076c87099bd8bd71c582.setIcon(icon_6b83ef52920400b4d465f01c96b0c6af);
#
#
#             var marker_f2d979656605595b3833bdf83771b1e5 = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_2a553afe07dc26207ec394afb520e360);
#
#
#             var icon_d8d8c351c3b4a94c7a6f1fb7e3299b39 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_f2d979656605595b3833bdf83771b1e5.setIcon(icon_d8d8c351c3b4a94c7a6f1fb7e3299b39);
#
#
#             var marker_1ccf9a148844547d326187a833c838dd = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_2a553afe07dc26207ec394afb520e360);
#
#
#             var icon_2fb35677b2048fd000ff8aceee195c3f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_1ccf9a148844547d326187a833c838dd.setIcon(icon_2fb35677b2048fd000ff8aceee195c3f);
#
#
#             var marker_51c3419c6ad7e5a2e4ccb35889f3a411 = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_2a553afe07dc26207ec394afb520e360);
#
#
#             var icon_225c9b399ce1abec4bd11ac6b4e951cf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_51c3419c6ad7e5a2e4ccb35889f3a411.setIcon(icon_225c9b399ce1abec4bd11ac6b4e951cf);
#
#
#             var marker_8dddd27199bb031930e858e71c72477b = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_2a553afe07dc26207ec394afb520e360);
#
#
#             var icon_382ea43f95951aa754ab595b470b9720 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;purple&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses
