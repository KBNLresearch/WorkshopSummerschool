# %% [markdown]
# ## Extra: example NER on a map

# %%
import spacy
from spacy import displacy
from collections import Counter
import pickle

# %%
import pandas as pd
import plotly.express as px
import pickle
import spacy
from spacy import displacy
from collections import Counter
import matplotlib.pyplot as plt
import folium

# %%
fiets_nlp = pd.read_pickle("data/fiets_nlp.pkl")

# %%
fiets_nlp.head(2)
# Out:
#        Unnamed: 0                                         identifier     type  \
# 21061       84265  http://resolver.kb.nl/resolve?urn=MMKB23:00140...  artikel
# 21072       84295  http://resolver.kb.nl/resolve?urn=ddd:01011723...  artikel
#
#                                  title                 date  \
# 21061  BUITENLAND. POLITIEK OVERZICHT.  1880/05/26 00:00:00
# 21072              Gemengde Berichten.  1869/09/20 00:00:00
#
#                                                  content subcategory category  \
# 21061  ’s Gravenhage, 25 Mei.’t Is te Berlijn een lie...       fiets    fiets
# 21072  Naar men verneemt, bloeit thans in den Hortus ...     rijwiel    fiets
#
#        Year   DL score    spatial  length  \
# 21061  1880  71.212121  Landelijk     792
# 21072  1869  77.823129  Landelijk     735
#
#                                                      doc
# 21061  (’s, Gravenhage, ,, 25, Mei.’t, Is, te, Berlij...
# 21072  (Naar, men, verneemt, ,, bloeit, thans, in, de...

# %%
fiets_nlp.Year.value_counts()
# Out:
# 1869    70
# 1883    27
# 1875    20
# 1884    16
# 1871    16
# 1876    14
# 1879    14
# 1870    12
# 1874    12
# 1878    12
# 1880    11
# 1872     9
# 1882     9
# 1881     7
# 1873     5
# 1877     1
# Name: Year, dtype: int64

# %%
def get_ner(doc, entity):
    return [ent.text for ent in doc.ents if ent.label_ == entity]

# %%
fiets_nlp['GPE'] = fiets_nlp['doc'].apply(lambda x: get_ner(x, 'GPE'))

# %%
# Load coordinates data from CSV
coordinates_df = pd.read_csv('data/nl.csv')
coordinates_df.head(2)
# Out:
#         city      lat     lng      country iso2     admin_name  capital  \
# 0    Tilburg  51.5500  5.0833  Netherlands   NL  Noord-Brabant    minor
# 1  Amsterdam  52.3728  4.8936  Netherlands   NL  Noord-Holland  primary
#
#    population  population_proper
# 0     1944588            1944588
# 1     1459402             917923

# %%
# Load coordinates data from CSV
coordinates_df = pd.read_csv('data/worldcities.csv')
coordinates_df.head(2)
# Out:
#       city city_ascii     lat       lng    country iso2 iso3 admin_name  \
# 0    Tokyo      Tokyo  35.687  139.7495      Japan   JP  JPN      Tōkyō
# 1  Jakarta    Jakarta  -6.175  106.8275  Indonesia   ID  IDN    Jakarta
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077

# %%
# Create a Python dictionary mapping city names to coordinates
city_to_coords = {row['city']: (row['lat'], row['lng']) for idx, row in coordinates_df.iterrows()}

# %%
# Function to get coordinates for GPEs
def get_gpe_coords(gpe_list):
    return [city_to_coords[gpe] for gpe in gpe_list if gpe in city_to_coords]

# Apply the function to create a new column with coordinates
fiets_nlp['GPE_coords'] = fiets_nlp['GPE'].apply(get_gpe_coords)

# Display the DataFrame
pd.set_option('display.max_colwidth', None)
display(fiets_nlp[['identifier','GPE','GPE_coords']].head())
# Out:
#                                                                  identifier  \
# 21061  http://resolver.kb.nl/resolve?urn=MMKB23:001409122:mpeg21:a00001:ocr
# 21072      http://resolver.kb.nl/resolve?urn=ddd:010117239:mpeg21:a0029:ocr
# 21076      http://resolver.kb.nl/resolve?urn=ddd:010263245:mpeg21:a0008:ocr
# 21078      http://resolver.kb.nl/resolve?urn=ddd:010117225:mpeg21:a0014:ocr
# 21079      http://resolver.kb.nl/resolve?urn=ddd:010097660:mpeg21:a0006:ocr
#
#                                                                                                GPE  \
# 21061  [Berlijn, Rome, Rome, nagaat, Granlle, Berlijn, Gladgesticht, G, Europa, Granville, Parijs]
# 21072                                                      [Zwolle, Zondag, Gorinchem, Californië]
# 21076                             [Frankrijk, Parijs, Parijs, Commun, Parijs, Rothschild, Berlijn]
# 21078                                 [gemeente Zype, Edinburg, Amerika, Parijs, Bardin, Engeland]
# 21079           [Pari, afgeloopon, Neder_nd, Do Gazelle van Antwerpen, België, Nederland, Brussel]
#
#                                                          GPE_coords
# 21061  [(43.226, -75.4909), (43.226, -75.4909), (48.8374, -1.5939)]
# 21072                           [(52.5167, 6.1), (51.8306, 4.9742)]
# 21076                                                            []
# 21078                                         [(26.3196, -98.1597)]
# 21079                                         [(29.9707, -94.0015)]

# %%
# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for coords_list in fiets_nlp['GPE_coords']:
    for coords in coords_list:
        folium.Marker(location=coords).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3baf975a407c171c878780c047c6336a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3baf975a407c171c878780c047c6336a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3baf975a407c171c878780c047c6336a = L.map(
#                 &quot;map_3baf975a407c171c878780c047c6336a&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_822fdcd6ee17c3c7983596807a8e91ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_822fdcd6ee17c3c7983596807a8e91ad.addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_1dec20409d042d7bcc18277a68ff0b2d = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_068126234162e0aebbe068f36c46ae26 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_3bf87d123ea4cabd415bbf3a3b3480db = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_716e6d4d5405f25fdffff5aa0f5d9d31 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_3aecf9513ddff4522b14eeb5a3052e42 = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_0cbe45c0a8fcb3cef54f227fdd21ada3 = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_2a2e50c989be48ff9edcb615805fc623 = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_569f9ca3c6ba05978e6b176ad385cc23 = L.marker(
#                 [29.9707, -94.0015],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_5119c225a63b94b5ac0cc429b2f3e2b9 = L.marker(
#                 [38.0486, -84.7258],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_202939270968edd18753351370900421 = L.marker(
#                 [44.84, -0.58],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_635fde08b44e70be9b7580792030dd91 = L.marker(
#                 [43.2964, 5.37],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_a5cfbc7c6ea1ccfc83292be57c0fea64 = L.marker(
#                 [36.7325, 3.0872],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_961cd93ad086897cde38e244844a78d7 = L.marker(
#                 [42.8133, -74.0129],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_ddb2d390bada7837c570e7bbb5fc0d0a = L.marker(
#                 [42.942, -74.1906],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_6707333f3dd25e9a88924ae8672b56e0 = L.marker(
#                 [52.3833, 4.6333],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_254685c83801f6ceb173267257e49423 = L.marker(
#                 [52.25, 6.2],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_371f9ae7958d858b5c9265ef3044b0f4 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_0fba8d09d67811574d2af186d41f5c3b = L.marker(
#                 [51.8425, 5.8528],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_66dedb94b122604284744e85d39567fe = L.marker(
#                 [52.21, 5.97],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c047c6336a);
#
#
#             var marker_cdefdba0a2071b43835c31150392a1bf = L.marker(
#                 [52.0908, 5.1217],
#                 {
# }
#             ).addTo(map_3baf975a407c171c878780c04

# %%
fiets_nlp.Year.unique()
# Out:
# array([1880, 1869, 1870, 1874, 1883, 1875, 1876, 1879, 1884, 1873, 1878,
#        1871, 1872, 1881, 1882, 1877], dtype=int64)

# %%
# Define a color mapping for each unique krantnaam
color_mapping = {
    1869: 'blue',
    1870: 'green',
    1871: 'red',
    1872: 'yellow',
    1873: 'orange',
    1874: 'brown',
    1875: 'purple',
    1876: 'lightblue',
    1877: 'pink',
    1878: 'magenta',
    1879: 'darkgreen',
    1880: 'darkblue',
    1881: 'black',  
    1882: 'black', 
    1883: 'black' ,
    1884: 'black'
    
}

# Plot the coordinates on a map
map = folium.Map(location=[52.0, 5.0], zoom_start=7)

for index, row in fiets_nlp.iterrows():
    krantnaam = row['Year']
    coords_list = row['GPE_coords']
    color = color_mapping.get(krantnaam, 'black')  # Default to black if krantnaam not in mapping
    
    for coords in coords_list:
        folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)

# Save the map to an HTML file
map.save('map.html')

# Display the map
map
# Out:
# C:\Users\mirjam\AppData\Local\Temp\ipykernel_24412\82490591.py:31: UserWarning: color argument of Icon should be one of: {'white', 'gray', 'black', 'blue', 'purple', 'darkpurple', 'lightblue', 'red', 'beige', 'darkred', 'pink', 'darkblue', 'lightgray', 'orange', 'lightgreen', 'cadetblue', 'green', 'darkgreen', 'lightred'}.
#   folium.Marker(location=coords, icon=folium.Icon(color=color)).add_to(map)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9064f16f1a01018a353d51fb3af410ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9064f16f1a01018a353d51fb3af410ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9064f16f1a01018a353d51fb3af410ef = L.map(
#                 &quot;map_9064f16f1a01018a353d51fb3af410ef&quot;,
#                 {
#                     center: [52.0, 5.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4aabd6bab0903515c66a62d688fedd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4aabd6bab0903515c66a62d688fedd3.addTo(map_9064f16f1a01018a353d51fb3af410ef);
#
#
#             var marker_ebc575dc6499d574143fa1654c55f0a9 = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9064f16f1a01018a353d51fb3af410ef);
#
#
#             var icon_9d67f096a2562ce14dbdbd7644ddb95a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_ebc575dc6499d574143fa1654c55f0a9.setIcon(icon_9d67f096a2562ce14dbdbd7644ddb95a);
#
#
#             var marker_83af16052abaad6638317afce2d80aff = L.marker(
#                 [43.226, -75.4909],
#                 {
# }
#             ).addTo(map_9064f16f1a01018a353d51fb3af410ef);
#
#
#             var icon_be60ffe09ec10edf2bd0b9c157936872 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_83af16052abaad6638317afce2d80aff.setIcon(icon_be60ffe09ec10edf2bd0b9c157936872);
#
#
#             var marker_3cc674635107400f991abca0602a8020 = L.marker(
#                 [48.8374, -1.5939],
#                 {
# }
#             ).addTo(map_9064f16f1a01018a353d51fb3af410ef);
#
#
#             var icon_4449fd08e4fd5dda5b71d26883518eab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_3cc674635107400f991abca0602a8020.setIcon(icon_4449fd08e4fd5dda5b71d26883518eab);
#
#
#             var marker_e199fe29d66c6e2ef9987d8e8cbdf9e8 = L.marker(
#                 [52.5167, 6.1],
#                 {
# }
#             ).addTo(map_9064f16f1a01018a353d51fb3af410ef);
#
#
#             var icon_f38bfed258a6facfaa000f9d5a899414 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_e199fe29d66c6e2ef9987d8e8cbdf9e8.setIcon(icon_f38bfed258a6facfaa000f9d5a899414);
#
#
#             var marker_7c338e6cadcc91bb8f1ecec92ccded4b = L.marker(
#                 [51.8306, 4.9742],
#                 {
# }
#             ).addTo(map_9064f16f1a01018a353d51fb3af410ef);
#
#
#             var icon_595406d1e771cd3cba0a6ff3fa143fdc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#                 marker_7c338e6cadcc91bb8f1ecec92ccded4b.setIcon(icon_595406d1e771cd3cba0a6ff3fa143fdc);
#
#
#             var marker_8a7f70a80130eec5f1bbb5c7f7b42800 = L.marker(
#                 [26.3196, -98.1597],
#                 {
# }
#             ).addTo(map_9064f16f1a01018a353d51fb3af410ef);
#
#
#             var icon_df242bb17e9faf639e0efc9a749901a6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;
